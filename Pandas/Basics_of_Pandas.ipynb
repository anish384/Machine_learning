# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name" : ['anish','harshal','avinash'],
    "marks" : [92,33,45],
    "city" : ['raychur', 'ahemdabad', 'takshashila']
}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#       name  marks         city
# 0    anish     92      raychur
# 1  harshal     33    ahemdabad
# 2  avinash     45  takshashila

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv', index = False)

# %%
df.head(2)
# Out:
#       name  marks       city
# 0    anish     92    raychur
# 1  harshal     33  ahemdabad

# %%
df.tail(2)
# Out:
#       name  marks         city
# 1  harshal     33    ahemdabad
# 2  avinash     45  takshashila

# %%
df.describe()
# Out:
#            marks
# count   3.000000
# mean   56.666667
# std    31.182260
# min    33.000000
# 25%    39.000000
# 50%    45.000000
# 75%    68.500000
# max    92.000000

# %%
anish = pd.read_csv('example.csv')

# %%
anish
# Out:
#    slno  name dist
# 0     1    50  abc
# 1     2    40  def
# 2     3    50  hij

# %%
anish['name']
# Out:
# 0    50
# 1    40
# 2    50
# Name: name, dtype: int64

# %%
anish['name'][0] = 10
# Out:
# <ipython-input-16-3bd7d5dab2ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anish['name'][0] = 10

# %%
anish
# Out:
#    slno  name dist
# 0     1    10  abc
# 1     2    40  def
# 2     3    50  hij

# %%
anish.to_csv('example.csv')

# %%
anish.index = ['first','second','third']

# %%
anish
# Out:
#         slno  name dist
# first      1    10  abc
# second     2    40  def
# third      3    50  hij
